# %%
import sklearn
import numpy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# load the csv data
df = pd.read_csv('Iris.csv')
df.head()
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df = df.drop(columns = ['Id'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df['SepalLengthCm'].hist()
# Out:
# <Axes: >

# %%
df['SepalWidthCm'].hist()
# Out:
# <Axes: >

# %%
df['PetalLengthCm'].hist()
# Out:
# <Axes: >

# %%
df['PetalWidthCm'].hist()
# Out:
# <Axes: >

# %%
colors = ['red', 'orange', 'blue']
species = ['virginica', 'versicolor', 'setosa']

# %%
unique_species = df['Species'].unique()

for species in unique_species:
    # Filter data for each species
    x = df[df['Species'] == species]
    
    # Plot the scatter plot
    plt.scatter(x['SepalLengthCm'], x['SepalWidthCm'], label=species)

plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.legend()
plt.title("Scatter Plot of Sepal Length vs Sepal Width for Iris Species")
plt.show()

# %%
unique_species = df['Species'].unique()

for species in unique_species:
    # Filter data for each species
    x = df[df['Species'] == species]
    
    # Plot the scatter plot
    plt.scatter(x['PetalLengthCm'], x['PetalWidthCm'], label=species)

plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.legend()
plt.title("Scatter Plot of Petal Length vs Petal Width for Iris Species")
plt.show()

# %%
unique_species = df['Species'].unique()

for species in unique_species:
    # Filter data for each species
    x = df[df['Species'] == species]
    
    # Plot the scatter plot
    plt.scatter(x['SepalLengthCm'], x['PetalLengthCm'], label=species)

plt.xlabel("Sepal Length (cm)")
plt.ylabel("Petal Length (cm)")
plt.legend()
plt.title("Scatter Plot of Sepal Length vs Petal Length for Iris Species")
plt.show()

# %%
unique_species = df['Species'].unique()

for species in unique_species:
    # Filter data for each species
    x = df[df['Species'] == species]
    
    # Plot the scatter plot
    plt.scatter(x['SepalWidthCm'], x['PetalWidthCm'], label=species)

plt.xlabel("Sepal Width (cm)")
plt.ylabel("Petal Width (cm)")
plt.legend()
plt.title("Scatter Plot of Sepal Width vs Petal Width for Iris Species")
plt.show()

# %%
dft = df.drop(columns=['Species'])
dft
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
dft.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
corr = dft.corr()
fig, ax = plt.subplots(figsize=(5,4))
sns.heatmap(corr, annot=True, ax=ax, cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
import pickle

X = df.drop(columns=['Species'])
Y = df['Species']
# split the data for train and test
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.30)

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
print("Logistic Regression Accuracy: ", model.score(x_test, y_test) * 100)
# Out:
# Logistic Regression Accuracy:  95.55555555555556

# %%
# model training
model.fit(x_train.values, y_train.values)
# Out:
# LogisticRegression()

# %%
# print metric to get 


print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  95.55555555555556

# %%
model = KNeighborsClassifier()
model.fit(x_train.values, y_train.values)
print("K-nearest neighbors Accuracy: ", model.score(x_test, y_test) * 100)
# Out:
# K-nearest neighbors Accuracy:  95.55555555555556

# %%
model.fit(x_train.values, y_train.values)
# Out:
# KNeighborsClassifier()

# %%
# print metric to get performance
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  95.55555555555556

# %%
# Decision Tree
model = DecisionTreeClassifier()
model.fit(x_train.values, y_train.values)
print("Decision Tree Accuracy: ", model.score(x_test, y_test) * 100)
# Out:
# Decision Tree Accuracy:  93.33333333333333

# %%
model.fit(x_train.values, y_train.values)
# Out:
# DecisionTreeClassifier()

# %%
# print metric to get performance
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  93.33333333333333

# %%
# save the model
#import pickle
#filename = 'saved_model.sav'
#pickle.dump(model, open(filename, 'wb'))

# %%
#import pickle

# %%
# Save the updated model
#filename = 'saved_model.sav'
#try:
  #  with open(filename, 'wb') as file:
   #     pickle.dump(model, file)
    #print("Model saved successfully.")
#except Exception as e:
 #   print(f"Error saving the model: {e}")

# %%
#load_model = pickle.load(open(filename, 'rb'))

# %%
#load_model.predict([[6.0, 2.2, 4.0, 1.0]])

# %%
import sklearn
print(sklearn.__version__)

# %%
x_test.head()

# %%
#load_model.predict([[4,3,1,5]])

# %%
#import joblib

# Save the updated model using joblib
#filename_joblib = 'saved_model1.joblib'
#try:
    #joblib.dump(model, filename_joblib)
    #print("Model saved successfully using joblib.")
#except Exception as e:
    #print(f"Error saving the model using joblib: {e}")

# %%
#import joblib

# Load the updated model using joblib
#filename_joblib = 'saved_model1.joblib'
#loaded_model = joblib.load(filename_joblib)

# Now you can use the "loaded_model" for inference or any other operations

# %%
#load_model.predict([[5,3,1,0.2]])

# %%
import pickle

# Assuming 'model' is your scikit-learn model
with open('saved_model1.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
import pickle

# Load the model
with open('saved_model1.pkl', 'rb') as file:
    model = pickle.load(file)
